# %%
# delete unneeded features
# is_night_game
# home_team_rest away_team_rest home_pitcher_rest away_pitcher_rest
# home_pitcher away_pitcher
# home_team_season away_team_season

# %%
import pandas as pd
data = pd.read_csv("preprocess_4.csv")
data['date'] = pd.to_datetime(data['date'])
data.head()
# Out:
#    id  home_team_abbr  away_team_abbr       date is_night_game  home_team_win  \
# 0   0              11              12 2021-05-16         False           True
# 1   1              25               8 2019-05-04          True          False
# 2   2              25              10 2019-06-10          True           True
# 3   3               0               3 2018-06-26          True           True
# 4   4              21               1 2016-07-05          True          False
#
#    home_pitcher  away_pitcher  home_team_rest  away_team_rest  ...  \
# 0         366.0         120.0             1.0             1.0  ...
# 1         613.0         637.0             2.0             NaN  ...
# 2         352.0         759.0             1.0             1.0  ...
# 3         186.0         360.0             1.0             1.0  ...
# 4         809.0          30.0             1.0             1.0  ...
#
#    away_pitcher_H_batters_faced_skew  away_pitcher_BB_batters_faced_mean  \
# ...

# %%
unneeded = [
"is_night_game"
,"home_team_rest"
,"away_team_rest"
,"home_pitcher_rest"
,"away_pitcher_rest"
,"home_pitcher"
,"away_pitcher"
,"home_team_season"
,"away_team_season"]

for feature in unneeded:
    data = data.drop(feature, axis = 1,  inplace = True)

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
data.to_csv("preprocess_5.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 data.to_csv("preprocess_5.csv", index = False)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'
